# %%
import sqlite3
import os
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd

# %%
BASE_DIR = globals()['_dh'][0]
DB_FILE = os.path.join(BASE_DIR,'db_snapshots/sensor_data_2026_03_09T18_18_to_2026-03-11T11_55.db')

conn = sqlite3.connect(DB_FILE)

df = pd.read_sql_query("SELECT * from sensor_data", conn)

df['timestamp'] = pd.to_datetime(df['timestamp'],format="%Y-%m-%dT%H:%M:%S")

#df['hour'] = df['timestamp'].dt.hour

print(df.head())
# Out:
#    id           timestamp  temperature   pressure  humidity  lux  hour
# 0   1 2026-03-09 18:48:04        23.90  101500.28     46.95   98    18
# 1   2 2026-03-09 18:48:22        23.90  101500.45     46.98   99    18
# 2   3 2026-03-09 18:49:22        23.92  101505.94     46.54   99    18
# 3   4 2026-03-09 18:50:08        22.50  101503.50     33.90   40    18
# 4   5 2026-03-09 18:51:08        20.53  101509.53     33.79   40    18

# %%
plt.plot(df['timestamp'], df['temperature'])
